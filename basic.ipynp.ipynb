# %% [markdown]
# BASIC PYTHON Questions

# %% [markdown]
# 1. What is Python, and why is it popular ?
#
#   -> Python is a programming language that is widely used in web applications, software development, data science, and machine learning . python is popular because easy to learn and can run on many different platforms.
#
# 2. What is an interpreter in Python ?
#
#   -> In Python, an interpreter is a program that reads and executes Python code line by line, without requiring it to be compiled into machine code first. It translates the code into machine-readable instructions and then executes them directly.
#
# 3. What are pre-defined keywords in Python ?
#
#   -> Python keywords are reserved words that have predefined meanings and purposes in the language. These keywords are an integral part of Python's syntax and cannot be used as identifiers (variable names, function names, etc.). They are always available and do not need to be imported.
#
#
#
# 4. Can keywords be used as variable names ?
#
#   ->  No, keywords cannot be used as variable names in most programming languages. Keywords are reserved words with specific meanings within the language, and using them as variable names would lead to conflicts and ambiguity.
#
#
#
# 5. What is mutability in Python ?
#
#   ->  In Python, mutability refers to an object's ability to be        changed after it is created. Mutable objects can be modified in place, meaning their internal state or data can be altered without creating a new object.
#
#
#
# 6. Why are lists mutable, but tuples are immutable ?
#
#   -> Tuples and lists are the same in every way except two: tuples use parentheses instead of square brackets, and the items in tuples cannot be modified (but the items in lists can be modified). We often call lists mutable (meaning they can be changed) and tuples immutable (meaning they cannot be changed).
#
#
#
# 7. What is the difference between “==” and “is” operators in Python ?
#
#   ->  He == and is operators in Python are both used for comparison, but they check for different things:
#
#   == Operator
# Checks for equality: The == operator compares the values of two objects. It returns True if the values are equal and False otherwise.
# Value-based comparison: It checks if the content or data held by the objects is the same.
# Customizable: The behavior of == can be customized by implementing the __eq__ method in a class.
#
# is Operator
# Checks for identity: The is operator compares the memory locations of two objects. It returns True if both variables refer to the same object in memory, and False otherwise.
# Reference-based comparison: It verifies if two references point to the exact same object in memory.
# Not customizable: The behavior of is cannot be modified.
#
#
# 8. What are logical operators in Python ?
#
#   -> Logical operators in Python are used to combine or modify conditional statements. They operate on boolean values (True or False) and return a boolean result. There are three main logical operators in Python.
#
# 9. What is type casting in Python ?
#
#   ->  Type casting, also known as type conversion, is the process of changing a variable's data type to another. This is done to ensure compatibility between different data types or to perform specific operations.
#
#   There are two main types of type casting in Python:
#
# 1. Implicit Type Conversion:
# Python automatically converts one data type to another in certain situations without the user's explicit intervention. This usually happens when performing operations involving different data types.
#
# 2.  Explicit Type Conversion:
# Explicit type conversion, also known as type casting, occurs when you deliberately convert a value from one data type to another using built-in functions. This is necessary when Python's implicit conversion does not meet your requirements.
#
#
# 10. What is the difference between implicit and explicit type casting ?
#
#   -> Implicit type casting, also known as widening or upcasting, is automatically performed by the compiler when a smaller data type is converted to a larger one. Explicit type casting, also known as narrowing or downcasting, requires the programmer to explicitly convert a larger data type to a smaller one, often involving the risk of data loss.
#
#
# 11. What is the purpose of conditional statements in Python ?
#
#    -> Conditional statements in Python are used to control the flow of a program based on whether certain conditions are true or false. They allow you to execute different blocks of code depending on the outcome of these conditions.
#
# 12. How does the elif statement work ?
#
#   -> Elif' stands for 'else if' and is used in Python programming to test multiple conditions. It is written following an if statement in Python to check an alternative condition if the first condition is false. The code block under the elif statement will be executed only if its condition is true.
#
# 13. What is the difference between for and while loops ?
#
#   -> The primary difference between for and while loops lies in their purpose and the nature of their execution. for loops are typically used when you know how many times you want to iterate or when you need to process each element of a sequence, while while loops are used when you want to repeat a block of code until a certain condition is met, which may not be a predetermined number of times.
#
# 14. Describe a scenario where a while loop is more suitable than a for loop ?
#
#   -> In programming, for loops are best used when you know the number of iterations ahead of time, whereas a while loop is best used when you don't know the number of iterations in advance. Both methods can help you iterate through your code.

# %% [markdown]
# # Write a Python program to print "Hello, World!
#
# '''
# print("hello world")
#
# '''
# #  Write a Python program that displays your name and age
#
# '''
# name = input("please Enter your name")
# Age =  int(input("please Enter your age"))
# print(f"name:{name}")
# print(f"Age:{Age}")
#
# '''
# #  Write code to print all the pre-defined keywords in Python using the keyword library.
#
# '''
# import keyword
#
# # printing the keywords
# print("Python keywords are...")
# print(keyword.kwlist)
#
# '''
#
# # Write a program that checks if a given word is a Python keyword.
#
#
# '''
# import keyword
#
# def is_keyword(word):
#     """Checks if a given word is a Python keyword.
#
#     Args:
#         word: The word to check.
#
#     Returns:
#         True if the word is a keyword, False otherwise.
#     """
#     return keyword.iskeyword(word)
#
# # Example usage
# word1 = "for"
# word2 = "hello"
#
# print(f"'{word1}' is a keyword: {is_keyword(word1)}")
# print(f"'{word2}' is a keyword: {is_keyword(word2)}")
#
#
# '''
#
# # Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each.
#
# '''
# my_list = [1, 2, 3]
# my_tuple = (4, 5, 6)
#
# print("Original list:", my_list)
# print("Original tuple:", my_tuple)
#
# my_list[1] = 10
# print("Modified list:", my_list) # Output: [1, 10, 3]
#
#
# my_list[1] = 10
# print("Modified list:", my_list) # Output: [1, 10, 3]
#
# '''
#
#
# #  Write a function to demonstrate the behavior of mutable and immutable arguments.
#
# '''
# def modify_args(immutable_arg, mutable_arg):
#     """
#     Demonstrates the behavior of mutable and immutable arguments in Python.
#
#     Args:
#         immutable_arg: An immutable object (e.g., int, string, tuple).
#         mutable_arg: A mutable object (e.g., list, dictionary).
#     """
#
#     # Attempt to modify the immutable argument
#     immutable_arg = immutable_arg + 1  # This creates a new object
#     print(f"Inside the function - Immutable Arg: {immutable_arg}")
#
#     # Modify the mutable argument
#     mutable_arg.append(4)  # This modifies the original object
#     print(f"Inside the function - Mutable Arg: {mutable_arg}")
#
# # Example usage
# immutable_var = 5
# mutable_var = [1, 2, 3]
#
# print(f"Before function call - Immutable Var: {immutable_var}")
# print(f"Before function call - Mutable Var: {mutable_var}")
#
# modify_args(immutable_var, mutable_var)
#
# print(f"After function call - Immutable Var: {immutable_var}")
# print(f"After function call - Mutable Var: {mutable_var}")
#
# '''
#
# #  Write a program that performs basic arithmetic operations on two user-input numbers
#
# '''
# def arithmetic_operations():
#     try:
#         num1 = float(input("Enter the first number: "))
#         num2 = float(input("Enter the second number: "))
#     except ValueError:
#         print("Invalid input. Please enter numbers only.")
#         return
#
#     print("Addition:", num1 + num2)
#     print("Subtraction:", num1 - num2)
#     print("Multiplication:", num1 * num2)
#
#     if num2 == 0:
#         print("Division by zero is not allowed.")
#     else:
#         print("Division:", num1 / num2)
#
# if __name__ == "__main__":
#     arithmetic_operations()
#
#     '''
#
#  # Write a program to demonstrate the use of logical operators.
#
# '''
#
# x = 5
# y = 10
# print(x > 0 and y < 20)  # Output: True
# print(x > 5 and y < 20)  # Output: False
#
# # Logical OR operator (or)
# # Returns True if at least one of the operands is True, otherwise returns False
# x = 5
# y = 10
# print(x > 0 or y > 20)  # Output: True
# print(x > 5 or y > 20)  # Output: False
#
# # Logical NOT operator (not)
# # Returns True if the operand is False, and returns False if the operand is True
# x = 5
# print(not(x > 0))  # Output: False
# print(not(x > 10)) # Output: True
#
#
# '''
#
#
# #  Write a Python program to convert user input from string to integer, float, and boolean types
#
# '''
# def convert_input():
#     user_input = input("Enter a value: ")
#
#     try:
#         # Attempt to convert to integer
#         integer_value = int(user_input)
#         print(f"Integer: {integer_value}")
#     except ValueError:
#         print("Not an integer.")
#
#     try:
#         # Attempt to convert to float
#         float_value = float(user_input)
#         print(f"Float: {float_value}")
#     except ValueError:
#         print("Not a float.")
#
#     # Attempt to convert to boolean
#     if user_input.lower() == "true":
#         boolean_value = True
#         print(f"Boolean: {boolean_value}")
#     elif user_input.lower() == "false":
#         boolean_value = False
#         print(f"Boolean: {boolean_value}")
#     else:
#         print("Not a boolean.")
#
# convert_input()
#
# '''
#
#
# # Write code to demonstrate type casting with list elements.
#
# '''
# # Initial list with mixed data types
# my_list = [1, 2.5, "3", True]
#
# # Type casting each element to integer
# int_list = [int(x) for x in my_list]
# print("Integer list:", int_list)
#
# # Type casting each element to float
# float_list = [float(x) for x in my_list]
# print("Float list:", float_list)
#
# # Type casting each element to string
# str_list = [str(x) for x in my_list]
# print("String list:", str_list)
#
# # Type casting each element to boolean
# bool_list = [bool(x) for x in my_list]
# print("Boolean list:", bool_list)
#
# '''
#
#
# #  Write a program that checks if a number is positive, negative, or zero.
#
# '''
# def check_number(num):
#   """Checks if a number is positive, negative, or zero."""
#
#   if num > 0:
#     print(f"{num} is positive.")
#   elif num < 0:
#     print(f"{num} is negative.")
#   else:
#     print("The number is zero.")
#
# # Example usage
# number = int(input("Enter a number: "))
# check_number(number)
#
# '''
#
# #  2. Write a for loop to print numbers from 1 to 10.
#
#
# '''
# for i in range(1, 11):
#     print(i)
#
# '''
#
#
# #  Write a Python program to find the sum of all even numbers between 1 and 50.
#
# '''
# total = 0
# for number in range(2, 51, 2):
#     total += number
# print(f"The sum of even numbers between 1 and 50 is: {total}")
#
# '''
#
# #   Write a program to reverse a string using a while loop.
#
#
# '''
# def reverse_string(s):
#     reversed_s = ""
#     i = len(s) - 1
#     while i >= 0:
#         reversed_s += s[i]
#         i -= 1
#     return reversed_s
#
# # Example usage
# string = "hello"
# reversed_string = reverse_string(string)
# print("Original string:", string)
# print("Reversed string:", reversed_string)
#
# '''
#
#
# # Write a Python program to calculate the factorial of a number provided by the user using a while loop.
#
#
# '''
#
# def factorial_while_loop(n):
#     """Calculates the factorial of a non-negative integer using a while loop.
#
#     Args:
#         n: The non-negative integer for which to calculate the factorial.
#
#     Returns:
#         The factorial of n, or 1 if n is 0.
#         Returns an error message if n is negative.
#     """
#
#     if n < 0:
#         return "Factorial is not defined for negative numbers."
#
#     result = 1
#     while n > 0:
#         result *= n
#         n -= 1
#     return result
#
# # Get input from the user
# try:
#     num = int(input("Enter a non-negative integer: "))
#     print("Factorial:", factorial_while_loop(num))
# except ValueError:
#     print("Invalid input. Please enter an integer.")
#
#
#     '''
